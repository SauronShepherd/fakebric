# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.master('local[2]').appName('fakebric-smoke').getOrCreate()
assert spark.range(4).count() == 4
print('fakebric-spark-ok')
spark.stop()
# Out:
# /opt/spark/bin/load-spark-env.sh: line 68: ps: command not found
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/08/31 03:23:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# [Stage 0:>                                                          (0 + 2) / 2]
# fakebric-spark-ok
